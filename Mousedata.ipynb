# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
#sr is study results table and mm is m
sr = pd.read_csv("Data/Study_results.csv")
mm = pd.read_csv("Data/Mouse_metadata.csv")
crt = pd.merge(mm, sr, how = "inner", on = "Mouse ID")
crt
#mm.sort_values(by=["Mouse ])
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# for i in range(0, 45,5):
#     selected = sr[~sr.where(sr["Timepoint"] ==i).isnull().any(axis=1)]
#     selected.sort_values(by=["Mouse ID"])
#     print(pd.concat([mm,selected], axis=1))
#     # mm = pd.concat([mm,selected])

# %%
mm["Drug Regimen"].nunique()
# Out:
# 10

# %%
drugs = set()
for i in mm["Drug Regimen"]:
    drugs.add(i)
drugs
# Out:
# {'Capomulin',
#  'Ceftamin',
#  'Infubinol',
#  'Ketapril',
#  'Naftisol',
#  'Placebo',
#  'Propriva',
#  'Ramicane',
#  'Stelasyn',
#  'Zoniferol'}

# %%
drugRegimenData = {}
for drug in drugs:
    
    drugRegimenData[drug] = mm[mm["Drug Regimen"] == drug]["Mouse ID"].tolist()

# %%
# I created a dictionary where I seperated mouse id by drug regimen, namely drugRegimenData
drugRegimenData

# %%
newDrugDataFrame = {}
for drug in drugRegimenData.keys():
    totalTumorVolume = 0
    for mouseId in drugRegimenData[drug]:
       print(sr[sr["Mouse ID"] == mouseId]["Tumor Volume (mm3)"].mean)
    newDrugDataFrame[drug] = totalTumorVolume
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 66      45.000000
# 477     38.825898
# 654     35.014271
# 745     34.223992
# 1034    32.997729
# 1217    33.464577
# 1374    31.099498
# 1605    26.546993
# 1628    24.365505
# 1814    22.050126
# Name: Tumor Volume (mm3), dtype: float64>
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 72      45.000000
# 396     45.851531
# 616     40.170558
# 806     40.678129
# 1031    41.211897
# 1234    35.569399
# 1428    34.952583
# 1620    30.960392
# 1639    31.369406
# 1870    29.128472
# Name: Tumor Volume (mm3), dtype: float64>
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 78      45.000000
# 441     38.711872
# 705     34.850998
# 770     35.276906
# 1057    35.928651
# 1294    36.338569
# 1417    35.474022
# 1604    35.846141
# 1632    32.798171
# 1795    30.276232
# Name: Tumor Volume (mm3), dtype: float64>
# ...

# %%
newDrugDataFrame
# Out:
# {'Ramicane': 66     NaN
#  477    NaN
#  654    NaN
#  745    NaN
#  1034   NaN
#  1217   NaN
#  1374   NaN
#  1605   NaN
#  1628   NaN
#  1814   NaN
#  Name: Tumor Volume (mm3), dtype: float64,
#  'Propriva': 168    NaN
#  345    NaN
#  685    NaN
#  875    NaN
#  937    NaN
#  1221   NaN
#  1335   NaN
#  1606   NaN
#  1681   NaN
#  1824   NaN
#  Name: Tumor Volume (mm3), dtype: float64,
#  'Stelasyn': 91     NaN
#  331    NaN
#  507    NaN
#  905    NaN
#  1070   NaN
#  1197   NaN
#  1401   NaN
#  Name: Tumor Volume (mm3), dtype: float64,
#  'Placebo': 144    NaN
#  471    NaN
#  688    NaN
#  718    NaN
#  945    NaN
#  1263   NaN
#  1382   NaN
#  1612   NaN
#  1621   NaN
#  1783   NaN
#  Name: Tumor Volume (mm3), dtype: float64,
#  'Infubinol': 113    NaN
#  389    NaN
#  598    NaN
#  758    NaN
#  1018   NaN
#  1295   NaN
#  1315   NaN
#  1577   NaN
#  1675   NaN
#  1804   NaN
#  Name: Tumor Volume (mm3), dtype: float64,
#  'Capomulin': 228    NaN
#  447    NaN
#  671    NaN
# ...
